# %%
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import SnowballStemmer

from nltk.corpus import stopwords

fake=pd.read_csv("Fake.csv")
genuine=pd.read_csv("True.csv")

# %%
fake['target']=0
genuine['target']=1

# %%
Data=pd.concat([fake,genuine],axis=0)
date=Data.reset_index(drop=True)
Data=Data.drop(['subject','date','title'],axis=1)

# %%
Data['text']=Data['text'].apply(word_tokenize)

#print(Data.head(10))

# %%
from nltk.stem.snowball import SnowballStemmer
porter=SnowballStemmer('english',ignore_stopwords=False)
def stem_it(text):
    return[porter.stem(word) for word in text]

Data['text']=Data['text'].apply(stem_it)
#print(Data.head(10))

# %%
def stop_it(t):
    dt=[word for word in t if len(word)>2]
    return

# %%
Data['text']=Data['text'].apply(stop_it)

display(Data.head(10))
# Out:
#    text  target
# 0  None       0
# 1  None       0
# 2  None       0
# 3  None       0
# 4  None       0
# 5  None       0
# 6  None       0
# 7  None       0
# 8  None       0
# 9  None       0

# %%
#Data['text']=Data['text'].apply(' '.join)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data['text'],data['target'])
display(X_train.head())
print('\n')
display(y_train.head())
# Out:
# 9256     Rabid, Trump-hating, anti-gun, comedian, and s...
# 1460     Talk of impeachment has been commonplace in Co...
# 20155    Can you blame her for losing her cool with Cro...
# 11208    The most laughable  news  network in America j...
# 5993     GENEVA (Reuters) - The International Committee...
# Name: text, dtype: object
# 9256     0
# 1460     0
# 20155    0
# 11208    0
# 5993     1
# Name: target, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
my_tfidf=TfidfVectorizer(max_df=0.7)

tfidf_train=my_tfidf.fit_transform(X_train)
tfidf_test=my_tfidf.fit_transform(X_test)

print(tfidf_train)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 6642072 stored elements and shape (33673, 108846)>
#   Coords	Values
#   (0, 79317)	0.09013436427254913
#   (0, 99042)	0.1146997668974074
#   (0, 44909)	0.0872118757093564
#   (0, 10924)	0.04391205528932366
#   (0, 43538)	0.057044219557866475
#   (0, 24057)	0.1577303858755982
#   (0, 90449)	0.05358570936405368
#   (0, 19746)	0.05060764244054953
#   (0, 12851)	0.10132768662167997
#   (0, 63590)	0.24565535387655962
#   (0, 47924)	0.41437409946735104
#   (0, 16288)	0.3309285076685361
#   (0, 97859)	0.019797342941988528
#   (0, 99791)	0.01882507856731545
#   (0, 10870)	0.05703394559119692
#   (0, 79053)	0.04733520291430432
#   (0, 7533)	0.04464981960572938
#   (0, 47164)	0.04652581785660031
#   (0, 44972)	0.045934924087262005
#   (0, 22179)	0.07216509728987262
#   (0, 44793)	0.01863682934195465
#   (0, 21582)	0.061273913201653714
#   (0, 46290)	0.08177768327787932
#   (0, 24064)	0.08357099341753443
#   (0, 69409)	0.01875965677302607
#   :	:
#   (33672, 17560)	0.06220590380492625
#   (33672, 46969)	0.04970129076139151
#   (33672, 9845)	0.05302231453383021
#   (33672, 93485)	0.06456658540768145
#   (33672, 58583)	0.04497508573238265
#   (33672, 82135)	0.06979674943318004
#   (33672, 29439)	0.06356901149984333
#   (33672, 69458)	0.06862894666015364
#   (33672, 58408)	0.05560636549011527
#   (33672, 46336)	0.21275730975300394
#   (33672, 94133)	0.05761197952586131
#   (33672, 15891)	0.05766684666633907
#   (33672, 100234)	0.05411072455894893
#   (33672, 25850)	0.5213743746121535
#   (33672, 100823)	0.08537022235275767
#   (33672, 7438)	0.07000676676133342
#   (33672, 24326)	0.06542557290716648
#   (33672, 82127)	0.07215210895513896
#   (33672, 102615)	0.08966387067856438
#   (33672, 22816)	0.06542557290716648
#   (33672, 74174)	0.0809349378343327
#   (33672, 74172)	0.08025793546505867
#   (33672, 40629)	0.15066802602432158
#   (33672, 88779)	0.08659007855111302
#   (33672, 99084)	0.09433044227032386

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import accuracy_score

# %%
model_1=LogisticRegression(max_iter=900)
model_1.fit(tfidf_train,y_train)
pred_1 = model_1.predict(tfidf_train)
cr1= accuracy_score(y_train,pred_1)
print(cr1*100)
# Out:
# 99.10610875181897

# %%
from sklearn.linear_model import PassiveAggressiveClassifier

model=PassiveAggressiveClassifier(max_iter=50)
model.fit(tfidf_train,y_train)
# Out:
# PassiveAggressiveClassifier(max_iter=50)

# %%
y_pred=model.predict(tfidf_train)
accscore=accuracy_score(y_pred,y_train)  
print("accuracy is ",accscore*100)
# Out:
# accuracy is  99.99703026163395
